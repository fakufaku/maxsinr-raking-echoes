# %%
import pandas as pd
from pathlib import Path

# %%
path = Path("./results/")
df = pd.concat(map(pd.read_csv, path.rglob("*.csv")), ignore_index=True)

# %%
df.pivot_table(
    index=["BF", "mask"], 
    values=["SIR_in", "SIR_out", "iSIR"]
).style.background_gradient(cmap='viridis', axis=0)
# Out:
# <style type="text/css">
# #T_223c4_row0_col0, #T_223c4_row1_col0, #T_223c4_row2_col0, #T_223c4_row3_col0, #T_223c4_row4_col0, #T_223c4_row5_col0, #T_223c4_row6_col0, #T_223c4_row7_col0, #T_223c4_row7_col1, #T_223c4_row7_col2, #T_223c4_row8_col0, #T_223c4_row9_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_223c4_row0_col1, #T_223c4_row0_col2, #T_223c4_row1_col1, #T_223c4_row1_col2 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_223c4_row2_col1, #T_223c4_row2_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_223c4_row3_col1, #T_223c4_row3_col2 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_223c4_row4_col1, #T_223c4_row4_col2, #T_223c4_row5_col1, #T_223c4_row5_col2 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_223c4_row6_col1, #T_223c4_row6_col2 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_223c4_row8_col1, #T_223c4_row8_col2 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_223c4_row9_col1, #T_223c4_row9_col2 {
#   background-color: #52c569;
#   color: #000000;
# }
# </style>
# <table id="T_223c4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_223c4_level0_col0" class="col_heading level0 col0" >SIR_in</th>
#       <th id="T_223c4_level0_col1" class="col_heading level0 col1" >SIR_out</th>
#       <th id="T_223c4_level0_col2" class="col_heading level0 col2" >iSIR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >BF</th>
#       <th class="index_name level1" >mask</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_223c4_level0_row0" class="row_heading level0 row0" rowspan="2">ds</th>
#       <th id="T_223c4_level1_row0" class="row_heading level1 row0" >led</th>
#       <td id="T_223c4_row0_col0" class="data row0 col0" >5.595139</td>
#       <td id="T_223c4_row0_col1" class="data row0 col1" >12.449641</td>
#       <td id="T_223c4_row0_col2" class="data row0 col2" >6.854502</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level1_row1" class="row_heading level1 row1" >oracle</th>
#       <td id="T_223c4_row1_col0" class="data row1 col0" >5.595139</td>
#       <td id="T_223c4_row1_col1" class="data row1 col1" >12.449641</td>
#       <td id="T_223c4_row1_col2" class="data row1 col2" >6.854502</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level0_row2" class="row_heading level0 row2" rowspan="2">maxsinr</th>
#       <th id="T_223c4_level1_row2" class="row_heading level1 row2" >led</th>
#       <td id="T_223c4_row2_col0" class="data row2 col0" >5.595139</td>
#       <td id="T_223c4_row2_col1" class="data row2 col1" >31.544022</td>
#       <td id="T_223c4_row2_col2" class="data row2 col2" >25.948883</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level1_row3" class="row_heading level1 row3" >oracle</th>
#       <td id="T_223c4_row3_col0" class="data row3 col0" >5.595139</td>
#       <td id="T_223c4_row3_col1" class="data row3 col1" >21.515158</td>
#       <td id="T_223c4_row3_col2" class="data row3 col2" >15.920019</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level0_row4" class="row_heading level0 row4" rowspan="2">mpdr</th>
#       <th id="T_223c4_level1_row4" class="row_heading level1 row4" >led</th>
#       <td id="T_223c4_row4_col0" class="data row4 col0" >5.595139</td>
#       <td id="T_223c4_row4_col1" class="data row4 col1" >5.587070</td>
#       <td id="T_223c4_row4_col2" class="data row4 col2" >-0.008069</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level1_row5" class="row_heading level1 row5" >oracle</th>
#       <td id="T_223c4_row5_col0" class="data row5 col0" >5.595139</td>
#       <td id="T_223c4_row5_col1" class="data row5 col1" >5.587070</td>
#       <td id="T_223c4_row5_col2" class="data row5 col2" >-0.008069</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level0_row6" class="row_heading level0 row6" rowspan="2">mvdr</th>
#       <th id="T_223c4_level1_row6" class="row_heading level1 row6" >led</th>
#       <td id="T_223c4_row6_col0" class="data row6 col0" >5.595139</td>
#       <td id="T_223c4_row6_col1" class="data row6 col1" >22.895679</td>
#       <td id="T_223c4_row6_col2" class="data row6 col2" >17.300540</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level1_row7" class="row_heading level1 row7" >oracle</th>
#       <td id="T_223c4_row7_col0" class="data row7 col0" >5.595139</td>
#       <td id="T_223c4_row7_col1" class="data row7 col1" >5.270377</td>
#       <td id="T_223c4_row7_col2" class="data row7 col2" >-0.324762</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level0_row8" class="row_heading level0 row8" rowspan="2">souden_mvdr</th>
#       <th id="T_223c4_level1_row8" class="row_heading level1 row8" >led</th>
#       <td id="T_223c4_row8_col0" class="data row8 col0" >5.595139</td>
#       <td id="T_223c4_row8_col1" class="data row8 col1" >30.390337</td>
#       <td id="T_223c4_row8_col2" class="data row8 col2" >24.795198</td>
#     </tr>
#     <tr>
#       <th id="T_223c4_level1_row9" class="row_heading level1 row9" >oracle</th>
#       <td id="T_223c4_row9_col0" class="data row9 col0" >5.595139</td>
#       <td id="T_223c4_row9_col1" class="data row9 col1" >24.374646</td>
#       <td id="T_223c4_row9_col2" class="data row9 col2" >18.779507</td>
#     </tr>
#   </tbody>
# </table>
