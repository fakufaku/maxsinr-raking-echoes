# %%
import pandas as pd # type: ignore
from pathlib import Path

import matplotlib.pyplot as plt # type: ignore
import seaborn as sns # type: ignore
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
sns.set(style='whitegrid', context='paper', font_scale=1.2,
    rc={
        'figure.figsize':(3.5,3.15), 
        'lines.linewidth':2.,
        'font.family': 'sans-serif',
        'font.sans-serif': [u'Helvetica'],
        'text.usetex': False,
})

# %%
path = Path("../results/")
df = pd.concat(map(pd.read_csv, path.glob("exp1_results*_per_image.csv")), ignore_index=True)
df.columns
# Out:
# Index(['SIR', 'bf', 'RT60', 'noise_loc', 'mask', 'absorption', 'max_order',
#        'image_early_reflection_flag', 'image_walls', 'image_order',
#        'image_toas', 'image_doas_rad', 'image_coeffs', 'SDR_in', 'SIR_in',
#        'ref_mic_idx', 'SDR_out', 'SIR_out', 'iSDR', 'iSIR', 'OIR_k_out',
#        'IP_k_out', 'SP_k_out', 'SNR_k_out', 'Rakeness_k_out', 'bf_gain',
#        'corr_pooled_wtr_dp', 'corr_pooled_wrt_bf', 'DI_circ', 'DI_sph',
#        'DI_diff', 'DI_k'],
#       dtype='object')

# %%
df
# Out:
#      SIR        bf  RT60   noise_loc        mask  absorption  max_order  \
# 0     -5      mvdr   0.3  speech_doa  oracle_vad    0.425442         41
# 1     -5      mvdr   0.3  speech_doa  oracle_vad    0.425442         41
# 2     -5      mvdr   0.3  speech_doa  oracle_vad    0.425442         41
# 3     -5      mvdr   0.3  speech_doa  oracle_vad    0.425442         41
# 4     -5      mvdr   0.3  speech_doa  oracle_vad    0.425442         41
# ..   ...       ...   ...         ...         ...         ...        ...
# 565   -5  max_sinr   0.6  speech_doa  oracle_vad    0.212721         83
# 566   -5  max_sinr   0.6  speech_doa  oracle_vad    0.212721         83
# 567   -5  max_sinr   0.6  speech_doa  oracle_vad    0.212721         83
# 568   -5  max_sinr   0.6  speech_doa  oracle_vad    0.212721         83
# 569   -5  max_sinr   0.6  speech_doa  oracle_vad    0.212721         83
#
#      image_early_reflection_flag image_walls  image_order  ...   SP_k_out  \
# 0                           True      direct            0  ...  -0.000730
# 1                           True       north            1  ...  -1.882863
# 2                           True       floor            1  ...  -4.860591
# 3                           True       floor            2  ...  -5.989154
# 4                           True        ceil            1  ...  -9.349031
# ..                           ...         ...          ...  ...        ...
# 565                        False        west            1  ... -14.044695
# 566                        False       floor            5  ... -17.482646
# 567                        False        west            2  ... -14.981191
# 568                        False        west            2  ... -15.285947
# 569                        False        west            3  ... -16.203589
#
#      SNR_k_out  Rakeness_k_out   bf_gain  corr_pooled_wtr_dp  \
# 0    -2.155503       -4.901788  0.094401            1.000000
# 1    -4.037636       -6.783921  0.036859            0.392620
# 2    -7.015365       -9.761649  0.027964            0.759866
# 3    -8.143928      -10.890213  0.014575            0.431465
# 4   -11.503805      -14.250089  0.009353            0.444346
# ..         ...             ...       ...                 ...
# 565 -23.949596      -19.826527  0.003604            0.369988
# 566 -27.387548      -23.264479  0.002988            0.421207
# 567 -24.886092      -20.763023  0.003745            0.296265
# 568 -25.190849      -21.067779  0.002732            0.369150
# 569 -26.108490      -21.985421  0.002837            0.298022
#
#      corr_pooled_wrt_bf   DI_circ    DI_sph       DI_diff      DI_k
# 0              0.461457  0.001885  0.033569   4774.247652  0.033353
# 1              0.303399  0.001885  0.033569   4774.247652  0.028056
# 2              0.339170  0.001885  0.033569   4774.247652  0.022104
# 3              0.287984  0.001885  0.033569   4774.247652  0.023762
# 4              0.234568  0.001885  0.033569   4774.247652  0.012414
# ..                  ...       ...       ...           ...       ...
# 565            0.117109  0.000966  0.023455  21352.684658  0.007194
# 566            0.155524  0.000966  0.023455  21352.684658  0.015669
# 567            0.136747  0.000966  0.023455  21352.684658  0.009718
# 568            0.116975  0.000966  0.023455  21352.684658  0.007121
# 569            0.136638  0.000966  0.023455  21352.684658  0.009604
#
# [570 rows x 32 columns]

# %% [markdown]
# ## General SDR and SIR

# %%
df.pivot_table(
    columns='bf', 
    index=['noise_loc', 'RT60', 'mask', 'SIR'], 
    values=['iSIR', 'iSDR'],
    aggfunc='mean'
).style.background_gradient(cmap='viridis', axis=0)
# Out:
# <style type="text/css">
# #T_31cf6_row0_col0, #T_31cf6_row0_col3, #T_31cf6_row2_col0, #T_31cf6_row2_col3, #T_31cf6_row4_col0, #T_31cf6_row4_col3, #T_31cf6_row6_col0, #T_31cf6_row6_col3, #T_31cf6_row7_col2, #T_31cf6_row7_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_31cf6_row0_col1 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_31cf6_row0_col2, #T_31cf6_row5_col0, #T_31cf6_row6_col4, #T_31cf6_row6_col5, #T_31cf6_row7_col1, #T_31cf6_row7_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_31cf6_row0_col4, #T_31cf6_row0_col5, #T_31cf6_row1_col3, #T_31cf6_row3_col0, #T_31cf6_row5_col1, #T_31cf6_row6_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_31cf6_row1_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_31cf6_row1_col1, #T_31cf6_row6_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_31cf6_row1_col2 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_31cf6_row1_col4 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_31cf6_row1_col5 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_31cf6_row2_col1 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_31cf6_row2_col2 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_31cf6_row2_col4 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_31cf6_row2_col5 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_31cf6_row3_col1 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_31cf6_row3_col2 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_31cf6_row3_col3 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_31cf6_row3_col4 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_31cf6_row3_col5 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_31cf6_row4_col1 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_31cf6_row4_col2 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_31cf6_row4_col4 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_31cf6_row4_col5 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_31cf6_row5_col2 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_31cf6_row5_col3 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_31cf6_row5_col4 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_31cf6_row5_col5 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_31cf6_row7_col0 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_31cf6_row7_col4 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_31cf6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31cf6_level0_col0" class="col_heading level0 col0" colspan="3">iSDR</th>
#       <th id="T_31cf6_level0_col3" class="col_heading level0 col3" colspan="3">iSIR</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >bf</th>
#       <th id="T_31cf6_level1_col0" class="col_heading level1 col0" >ds</th>
#       <th id="T_31cf6_level1_col1" class="col_heading level1 col1" >max_sinr</th>
#       <th id="T_31cf6_level1_col2" class="col_heading level1 col2" >mvdr</th>
#       <th id="T_31cf6_level1_col3" class="col_heading level1 col3" >ds</th>
#       <th id="T_31cf6_level1_col4" class="col_heading level1 col4" >max_sinr</th>
#       <th id="T_31cf6_level1_col5" class="col_heading level1 col5" >mvdr</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >noise_loc</th>
#       <th class="index_name level1" >RT60</th>
#       <th class="index_name level2" >mask</th>
#       <th class="index_name level3" >SIR</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31cf6_level0_row0" class="row_heading level0 row0" rowspan="4">noise_doa</th>
#       <th id="T_31cf6_level1_row0" class="row_heading level1 row0" rowspan="2">0.300000</th>
#       <th id="T_31cf6_level2_row0" class="row_heading level2 row0" >oracle_scm</th>
#       <th id="T_31cf6_level3_row0" class="row_heading level3 row0" >-5</th>
#       <td id="T_31cf6_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_31cf6_row0_col1" class="data row0 col1" >3.808909</td>
#       <td id="T_31cf6_row0_col2" class="data row0 col2" >4.795258</td>
#       <td id="T_31cf6_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_31cf6_row0_col4" class="data row0 col4" >26.047322</td>
#       <td id="T_31cf6_row0_col5" class="data row0 col5" >32.412008</td>
#     </tr>
#     <tr>
#       <th id="T_31cf6_level2_row1" class="row_heading level2 row1" >oracle_vad</th>
#       <th id="T_31cf6_level3_row1" class="row_heading level3 row1" >-5</th>
#       <td id="T_31cf6_row1_col0" class="data row1 col0" >3.180527</td>
#       <td id="T_31cf6_row1_col1" class="data row1 col1" >3.841048</td>
#       <td id="T_31cf6_row1_col2" class="data row1 col2" >5.010105</td>
#       <td id="T_31cf6_row1_col3" class="data row1 col3" >5.550337</td>
#       <td id="T_31cf6_row1_col4" class="data row1 col4" >25.705209</td>
#       <td id="T_31cf6_row1_col5" class="data row1 col5" >31.348253</td>
#     </tr>
#     <tr>
#       <th id="T_31cf6_level1_row2" class="row_heading level1 row2" rowspan="2">0.600000</th>
#       <th id="T_31cf6_level2_row2" class="row_heading level2 row2" >oracle_scm</th>
#       <th id="T_31cf6_level3_row2" class="row_heading level3 row2" >-5</th>
#       <td id="T_31cf6_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_31cf6_row2_col1" class="data row2 col1" >3.444505</td>
#       <td id="T_31cf6_row2_col2" class="data row2 col2" >7.145127</td>
#       <td id="T_31cf6_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_31cf6_row2_col4" class="data row2 col4" >17.905843</td>
#       <td id="T_31cf6_row2_col5" class="data row2 col5" >25.987338</td>
#     </tr>
#     <tr>
#       <th id="T_31cf6_level2_row3" class="row_heading level2 row3" >oracle_vad</th>
#       <th id="T_31cf6_level3_row3" class="row_heading level3 row3" >-5</th>
#       <td id="T_31cf6_row3_col0" class="data row3 col0" >3.609078</td>
#       <td id="T_31cf6_row3_col1" class="data row3 col1" >3.344043</td>
#       <td id="T_31cf6_row3_col2" class="data row3 col2" >7.442618</td>
#       <td id="T_31cf6_row3_col3" class="data row3 col3" >4.647079</td>
#       <td id="T_31cf6_row3_col4" class="data row3 col4" >20.918757</td>
#       <td id="T_31cf6_row3_col5" class="data row3 col5" >25.313156</td>
#     </tr>
#     <tr>
#       <th id="T_31cf6_level0_row4" class="row_heading level0 row4" rowspan="4">speech_doa</th>
#       <th id="T_31cf6_level1_row4" class="row_heading level1 row4" rowspan="2">0.300000</th>
#       <th id="T_31cf6_level2_row4" class="row_heading level2 row4" >oracle_scm</th>
#       <th id="T_31cf6_level3_row4" class="row_heading level3 row4" >-5</th>
#       <td id="T_31cf6_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_31cf6_row4_col1" class="data row4 col1" >4.195949</td>
#       <td id="T_31cf6_row4_col2" class="data row4 col2" >5.472989</td>
#       <td id="T_31cf6_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_31cf6_row4_col4" class="data row4 col4" >20.627447</td>
#       <td id="T_31cf6_row4_col5" class="data row4 col5" >26.709238</td>
#     </tr>
#     <tr>
#       <th id="T_31cf6_level2_row5" class="row_heading level2 row5" >oracle_vad</th>
#       <th id="T_31cf6_level3_row5" class="row_heading level3 row5" >-5</th>
#       <td id="T_31cf6_row5_col0" class="data row5 col0" >2.010798</td>
#       <td id="T_31cf6_row5_col1" class="data row5 col1" >4.483845</td>
#       <td id="T_31cf6_row5_col2" class="data row5 col2" >5.813113</td>
#       <td id="T_31cf6_row5_col3" class="data row5 col3" >5.036871</td>
#       <td id="T_31cf6_row5_col4" class="data row5 col4" >25.516303</td>
#       <td id="T_31cf6_row5_col5" class="data row5 col5" >23.037939</td>
#     </tr>
#     <tr>

# %%
bf_criteria = df['bf_criterion'].unique()
n_bf = len(bf_criteria)
pal = sns.cubehelix_palette(n_bf, start=0.5, rot=-0.5,dark=0.3, light=.75, reverse=True, hue=1.)
sns.set_palette(pal)

for metric in ['iwOIR_k', 'SP_k', 'SNR_k', 'correlation_k', 'DI_k', 'Rakeness_k' ]:
    tmp_df = df[df['SIR'] == 5]
    fig, ax = plt.subplots(figsize=(8, 3))
    sns.lineplot(x='image_name', y=metric, hue='bf_criterion', data=tmp_df, ax=ax)
    plt.xticks(rotation=45)
    plt.legend(title='Criterion')
    plt.tight_layout()
    plt.savefig(f'./fa2025_{metric}.pdf', dpi=300)
    plt.show()

# %%
sns.set(style='whitegrid', context='paper', font_scale=1.2,
        rc={
            'figure.figsize':(3.5,3.15), 
            'lines.linewidth':2.,
            'font.family': 'sans-serif',
            'font.sans-serif': [u'Helvetica'],
            'text.usetex': False,
            })
pal = sns.cubehelix_palette(n_masks, start=0.5, rot=-0.5,dark=0.3, light=.75, reverse=True, hue=1.)
sns.set_palette(pal)
